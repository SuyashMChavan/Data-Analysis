# %% [markdown]
# | Data Science Tools|
# | ------------------|
# | Jupyter Notebooks |
# | Visual Studio Code|
# | Anaconda GUI      |

# %% [markdown]
# ## Data Science Ecosystem
# ***

# %% [markdown]
# ### Introduction:
#
# Here we will introduce to the various functions of the jupyter notebook such as lists, tables, expressions and objectives of this course.

# %% [markdown]
# ### We will create a list of data science languages:
#
# 1. Python
# 2. R Language
# 3. C/C++
# These are some of the main languages used for data science

# %% [markdown]
# ### List of data science libraries:
#
# 1. Pandas - Used for data manipulation
# 2. Numpy - Used for numerical computing
# 3. Matplotlib - Used for data visualization
# These are some of the main datasciecne libraries.

# %% [markdown]
# ### List of data science tools:
#
# | Data Science Tools | Uses of Tools  |
# | ------------------ | -------------- |
# |      My SQL        | Data Storing   |
# |      ApacheSpark   | Data Transform |
# |      Pandas        | Data Model     |
# |      ggplot        | Data Visualize |
#
# ***

# %% [markdown]
# ## This is an introduction to arithmetic expression
# ***

# %%
## This is a simple arithmetic expression to multiply then add integers

## Evaluting expression:
(3*4)+5
# Out:
# 17

# %%
## This will convert 200 minutes to hours by dividing by 60
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives of this Course 2:
#
# 1. Learn about the tools used for datascience
# 2. Under the languages used data science for e.g. Python, and R
# 3. Understanding web based development envionments such as Jupyter Notebook and GUI based environments such as Anaconda3

# %% [markdown]
# ## Authors Name: Suyash M Chavan
